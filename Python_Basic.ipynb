# %% [markdown]
# <a href="https://colab.research.google.com/github/Manish91232316/IIT-Madras-Artificial-intelligence-with-Deep-lerning-Certification-Course/blob/master/Python_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once in a notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a text file.
uploaded = drive.CreateFile({'title': 'Sample file.txt'})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1mQ_rFv41NmlL4tYzeLioVX1cCDqYo0SQ

# %%
# Create & upload a text file.
uploaded = drive.CreateFile({'title': ' file2.txt'})
uploaded.SetContentString('Hellow world')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1B64i4AY6fIXRfMkO6ZwDr6rlvixPKZL2

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# List .txt files in the root.
#
# Search query reference:
# https://developers.google.com/drive/v2/web/search-parameters
listed = drive.ListFile({'q': "title contains '.txt' and 'root' in parents"}).GetList()
for file in listed:
  print('title {}, id {}'.format(file['title'], file['id']))
# Out:
# title  file2.txt, id 1B64i4AY6fIXRfMkO6ZwDr6rlvixPKZL2
# title Sample file.txt, id 1Y_hqp0W8EQ4jRT13iNC-n3vreh_tsY_E
# title Sample file.txt, id 1mQ_rFv41NmlL4tYzeLioVX1cCDqYo0SQ
# title Sample file.txt, id 1Vujk5YEhHViMdew9ZxY-PMzSme-XqkhO
# title Sample file.txt, id 1F3j3qCe4gQdqlE7HOmLkV82U5BarZXaX

# %%
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '16U8kEq-vFtjJDM9Qt01qvC76mqE5hKPE' #https://drive.google.com/open?id=16U8kEq-vFtjJDM9Qt01qvC76mqE5hKPE
downloaded = drive.CreateFile({'id': file_id})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
file_id = '16U8kEq-vFtjJDM9Qt01qvC76mqE5hKPE' #https://drive.google.com/open?id=16U8kEq-vFtjJDM9Qt01qvC76mqE5hKPE
downloaded = drive.CreateFile({'id': file_id})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
downloaded.GetContentFile('Amazon-movies and TV Ratings.csv')

# %%
# !ls
# Out:
#  adc.json  'Amazon-movies and TV Ratings.csv'   sample_data

# %%
import pandas as pd

# %%
df = pd.read_csv("Amazon-movies and TV Ratings.csv")

# %%
df.head()
# Out:
#           user_id  Movie1  Movie2  ...  Movie204  Movie205  Movie206
# 0  A3R5OBKS7OM2IR     5.0     5.0  ...       NaN       NaN       NaN
# 1   AH3QC2PC1VTGP     NaN     NaN  ...       NaN       NaN       NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN  ...       NaN       NaN       NaN
# 3   AVIY68KEPQ5ZD     NaN     NaN  ...       NaN       NaN       NaN
# 4  A1CV1WROP5KTTW     NaN     NaN  ...       NaN       NaN       NaN
#
# [5 rows x 207 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4848 entries, 0 to 4847
# Columns: 207 entries, user_id to Movie206
# dtypes: float64(206), object(1)
# memory usage: 7.7+ MB

# %%
df.tail()
# Out:
#              user_id  Movie1  Movie2  ...  Movie204  Movie205  Movie206
# 4843  A1IMQ9WMFYKWH5     NaN     NaN  ...       NaN       NaN       5.0
# 4844  A1KLIKPUF5E88I     NaN     NaN  ...       NaN       NaN       5.0
# 4845   A5HG6WFZLO10D     NaN     NaN  ...       NaN       NaN       5.0
# 4846  A3UU690TWXCG1X     NaN     NaN  ...       NaN       NaN       5.0
# 4847   AI4J762YI6S06     NaN     NaN  ...       NaN       NaN       5.0
#
# [5 rows x 207 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(df)
# Out:
# ['Movie1',
#  'Movie10',
#  'Movie11',
#  'Movie12',
#  'Movie13',
#  'Movie14',
#  'Movie15',
#  'Movie16',
#  'Movie17',
#  'Movie18',
#  'Movie19',
#  'Movie2',
#  'Movie20',
#  'Movie21',
#  'Movie22',
#  'Movie23',
#  'Movie24',
#  'Movie25',
#  'Movie26',
#  'Movie27',
#  'Movie28',
#  'Movie29',
#  'Movie3',
#  'Movie30',
#  'Movie31',
#  'Movie32',
#  'Movie33',
#  'Movie34',
#  'Movie35',
#  'Movie36',
#  'Movie37',
#  'Movie38',
#  'Movie39',
#  'Movie4',
#  'Movie40',
#  'Movie41',
#  'Movie42',
#  'Movie43',
#  'Movie44',
#  'Movie45',
#  'Movie46',
#  'Movie47',
#  'Movie48',
#  'Movie49',
#  'Movie5',
#  'Movie50',
#  'Movie51',
#  'Movie52',
#  'Movie53',
#  'Movie54',
#  'Movie55',
#  'Movie56',
#  'Movie57',
#  'Movie58',
#  'Movie59',
#  'Movie6',
#  'Movie60',
#  'Movie61',
#  'Movie62',
#  'Movie63',
#  'Movie64',
#  'Movie65',
#  'Movie66',
#  'Movie67',
#  'Movie68',
#  'Movie69',
#  'Movie7',
#  'Movie70',
#  'Movie71',
#  'Movie72',
#  'Movie73',
# ...

# %%
len(df)
# Out:
# 4848

# %%
df.shape
# Out:
# (4848, 207)

# %%
df.loc[5]
# Out:
# user_id     AP57WZ2X4G0AA
# Movie1                NaN
# Movie2                NaN
# Movie3                NaN
# Movie4                NaN
#                 ...
# Movie202              NaN
# Movie203              NaN
# Movie204              NaN
# Movie205              NaN
# Movie206              NaN
# Name: 5, Length: 207, dtype: object

# %%
df_shot = df[20:110]

# %%
df_shot.shape
# Out:
# (90, 207)

# %%
df_shot.head()
# Out:
#            user_id  Movie1  Movie2  ...  Movie204  Movie205  Movie206
# 20  A39ZX6X5H2N4TS     NaN     NaN  ...       NaN       NaN       NaN
# 21  A2Z3ZHQI6YXKHH     NaN     NaN  ...       NaN       NaN       NaN
# 22  A2RNKU9KJHQ2BV     NaN     NaN  ...       NaN       NaN       NaN
# 23  A30WLYNJA3B17H     NaN     NaN  ...       NaN       NaN       NaN
# 24  A3LI15T4YR5WD6     NaN     NaN  ...       NaN       NaN       NaN
#
# [5 rows x 207 columns]

# %%
df_thin = df[['user_id', 'Movie1', 'Movie2', 'Movie3', 'Movie4']]

# %%
df_thin.shape
# Out:
# (4848, 5)

# %%
df_thin.head()
# Out:
#           user_id  Movie1  Movie2  Movie3  Movie4
# 0  A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN
# 1   AH3QC2PC1VTGP     NaN     NaN     2.0     NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0
# 3   AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0
# 4  A1CV1WROP5KTTW     NaN     NaN     NaN     NaN

# %%
df_Movie4 = df_thin[df_thin['Movie4']==5.0]

# %%
df_Movie4.shape
# Out:
# (2, 5)

# %%
df_thin['Movie3'].describe()
# Out:
# count    1.0
# mean     2.0
# std      NaN
# min      2.0
# 25%      2.0
# 50%      2.0
# 75%      2.0
# max      2.0
# Name: Movie3, dtype: float64

# %%
df_thin.describe()

# %%
g = df_thin.groupby(['Movie3'])

# %%
for key , df_key in g:
  print(key)
  print(df_key)
# Out:
# 2.0
#          user_id  Movie1  Movie2  Movie3  Movie4
# 1  AH3QC2PC1VTGP     NaN     NaN     2.0     NaN

# %%
df_thin.groupby(['Movie3']).describe()
# Out:
#        Movie1                               ... Movie4
#         count mean std min 25% 50% 75% max  ...  count mean std min 25% 50% 75% max
# Movie3                                      ...
# 2.0       0.0  NaN NaN NaN NaN NaN NaN NaN  ...    0.0  NaN NaN NaN NaN NaN NaN NaN
#
# [1 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
ax = sns.pairplot(df_thin , diag_kind= 'hist', )
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# # DEBUGGING

# %%
import random

# %%
 def factorial(x):
   if (x==0):
     return 1
   return x * factorial(x - 1)

# %%
factorial(5)

# %%
def code_to_debug():
  import pdb; pdb.set_trace()
  for i in range(10):
    x = random.random()
    factorial(x)

# %%
# %xmode verbose

# %%
code_to_debug()
# Out:
# > <ipython-input-4-4af8ed541942>(3)code_to_debug()
# -> for i in range(10):
# > <ipython-input-4-4af8ed541942>(4)code_to_debug()
# -> x = random.random()
# > <ipython-input-4-4af8ed541942>(3)code_to_debug()
# -> for i in range(10):
# > <ipython-input-4-4af8ed541942>(4)code_to_debug()
# -> x = random.random()
# > <ipython-input-4-4af8ed541942>(3)code_to_debug()
# -> for i in range(10):
# > <ipython-input-4-4af8ed541942>(4)code_to_debug()
# -> x = random.random()
#
# Documented commands (type help <topic>):
# ...
# EOF    c          d        h         list      q        rv       undisplay
# a      cl         debug    help      ll        quit     s        unt
# alias  clear      disable  ignore    longlist  r        source   until
# args   commands   display  interact  n         restart  step     up
# b      condition  down     j         next      return   tbreak   w
# break  cont       enable   jump      p         retval   u        whatis
# ...

# %% [markdown]
# # VECTOR

# %%
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inine
